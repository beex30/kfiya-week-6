# %%
from src.data_preprocessing import load_data, detect_missing_values
from src.data_visualization import visualize_distribution, visualize_categorical, visualize_correlation, visualize_outliers

# %%
# Load the dataset
file_path = "../data/data.csv"
df = load_data(file_path)

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %%
# Display basic information about the dataset
print("Data Overview:")
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
print("\nData Types:")
print(df.dtypes)
print("\nMemory Usage:")
print(df.memory_usage(deep=True))
# Out:
# Data Overview:
# Number of rows: 95662
# Number of columns: 16
#
# Data Types:
# TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object
#
# Memory Usage:
# Index                       132
# TransactionId           6525022
# BatchId                 5951341
# AccountId               6013104
# SubscriptionId          6492670
# CustomerId              6110538
# CurrencyCode            4974424
# CountryCode              765296
# ProviderId              5835382
# ProductId               5772554
# ...

# %%
# Display summary statistics of numerical features
print("Summary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000

# %%
# Visualize the distribution of numerical features
visualize_distribution(df, 'Amount', 'blue')

# %%
visualize_distribution(df, 'Value', 'green')

# %%
# Visualize categorical features
visualize_categorical(df, 'CurrencyCode', 'FraudResult', 'Set2')

# %%
visualize_categorical(df, 'ProductCategory', 'FraudResult', 'Set2')

# %%
visualize_categorical(df, 'ChannelId', 'FraudResult', 'Set2')

# %%
# Correlation analysis for numerical features
visualize_correlation(df, ['Amount', 'Value'])

# %%
# Checking for missing values
missing_values = detect_missing_values(df)

# %%
print(f"Missing values in each column:\n{missing_values}")
# Out:
# Missing values in each column:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# Value                   0
# TransactionStartTime    0
# PricingStrategy         0
# FraudResult             0
# dtype: int64

# %%
# Identifying outliers using boxplots for Amount and Value
visualize_outliers(df, ['Amount', 'Value'])

# %%
# Visualizing Fraud Cases
visualize_categorical(df, 'FraudResult', 'FraudResult', 'Set1')
